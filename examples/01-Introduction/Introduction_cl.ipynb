# %%
import pickle
from pathlib import Path
import pandas as pd
import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run
from neuralhydrology.datasetzoo.basedataset import BaseDataset
from neuralhydrology.datasetzoo.camelscl import CamelsCL
from neuralhydrology.utils.config import Config
# Out:
# /tmp/ipykernel_3030369/4214423194.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU
if torch.cuda.is_available():
    start_run(config_file=Path("1_basin_cl.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("1_basin_cl.yml"), gpu=-1)
# Out:
# 2024-02-05 15:14:17,840: Logging to /home/sngrjohn/GitLab/neuralhydrology/examples/01-Introduction/runs/test_run_cl_0502_151417/output.log initialized.
# 2024-02-05 15:14:17,840: ### Folder structure created at /home/sngrjohn/GitLab/neuralhydrology/examples/01-Introduction/runs/test_run_cl_0502_151417
# 2024-02-05 15:14:17,841: ### Run configurations for test_run_cl
# 2024-02-05 15:14:17,841: experiment_name: test_run_cl
# 2024-02-05 15:14:17,841: train_basin_file: 1_basin_cl.txt
# 2024-02-05 15:14:17,842: validation_basin_file: 1_basin_cl.txt
# 2024-02-05 15:14:17,842: test_basin_file: 1_basin_cl.txt
# 2024-02-05 15:14:17,843: train_start_date: 2009-01-12 00:00:00
# 2024-02-05 15:14:17,843: train_end_date: 2011-06-16 00:00:00
# 2024-02-05 15:14:17,844: validation_start_date: 2006-01-12 00:00:00
# 2024-02-05 15:14:17,844: validation_end_date: 2007-01-12 00:00:00
# 2024-02-05 15:14:17,845: test_start_date: 2007-01-12 00:00:00
# 2024-02-05 15:14:17,845: test_end_date: 2008-01-12 00:00:00
# 2024-02-05 15:14:17,845: device: cpu
# 2024-02-05 15:14:17,846: validate_every: 3
# 2024-02-05 15:14:17,846: validate_n_random_basins: 1
# 2024-02-05 15:14:17,847: metrics: ['NSE']
# 2024-02-05 15:14:17,847: model: cudalstm
# 2024-02-05 15:14:17,848: head: regression
# 2024-02-05 15:14:17,848: output_activation: linear
# 2024-02-05 15:14:17,848: hidden_size: 20
# 2024-02-05 15:14:17,849: initial_forget_bias: 3
# 2024-02-05 15:14:17,849: output_dropout: 0.4
# 2024-02-05 15:14:17,850: optimizer: Adam
# 2024-02-05 15:14:17,850: loss: MSE
# 2024-02-05 15:14:17,850: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-02-05 15:14:17,850: batch_size: 256
# 2024-02-05 15:14:17,851: epochs: 50
# 2024-02-05 15:14:17,851: clip_gradient_norm: 1
# 2024-02-05 15:14:17,851: predict_last_n: 1
# 2024-02-05 15:14:17,852: seq_length: 365
# 2024-02-05 15:14:17,852: num_workers: 8
# 2024-02-05 15:14:17,852: log_interval: 5
# 2024-02-05 15:14:17,853: log_tensorboard: True
# 2024-02-05 15:14:17,853: log_n_figures: 1
# 2024-02-05 15:14:17,853: save_weights_every: 1
# 2024-02-05 15:14:17,854: dataset: camels_cl
# 2024-02-05 15:14:17,854: data_dir: ../../data/CAMELS_CL_v202201
# 2024-02-05 15:14:17,854: forcings: ['maurer', 'daymet', 'nldas']
# 2024-02-05 15:14:17,855: dynamic_inputs: ['tmax_cr2met_C', 'pet_hargreaves_mm', 'precip_mswep_mm', 'tmean_cr2met_C', 'tmin_cr2met_C', 'precip_cr2met_mm']
# 2024-02-05 15:14:17,855: target_variables: ['q_mm']
# 2024-02-05 15:14:17,855: clip_targets_to_zero: ['q_mm']
# 2024-02-05 15:14:17,855: number_of_basins: 1
# 2024-02-05 15:14:17,856: run_dir: /home/sngrjohn/GitLab/neuralhydrology/examples/01-Introduction/runs/test_run_cl_0502_151417
# 2024-02-05 15:14:17,856: train_dir: /home/sngrjohn/GitLab/neuralhydrology/examples/01-Introduction/runs/test_run_cl_0502_151417/train_data
# 2024-02-05 15:14:17,856: img_log_dir: /home/sngrjohn/GitLab/neuralhydrology/examples/01-Introduction/runs/test_run_cl_0502_151417/img_log
# 2024-02-05 15:14:17,858: ### Device cpu will be used for training
# 2024-02-05 15:14:17,858: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 44.57it/s]
# 2024-02-05 15:14:17,887: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00, 118.06it/s]
# # Epoch 1: 100%|██████████| 4/4 [00:00<00:00,  9.91it/s, Loss: 0.4117]
# 2024-02-05 15:14:18,320: Epoch 1 average loss: avg_loss: 0.50405, avg_total_loss: 0.50405
# # Epoch 2: 100%|██████████| 4/4 [00:00<00:00,  9.69it/s, Loss: 0.2285]
# 2024-02-05 15:14:18,737: Epoch 2 average loss: avg_loss: 0.32919, avg_total_loss: 0.32919
# # Epoch 3: 100%|██████████| 4/4 [00:00<00:00, 10.99it/s, Loss: 0.2249]
# 2024-02-05 15:14:19,104: Epoch 3 average loss: avg_loss: 0.32925, avg_total_loss: 0.32925
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 14.01it/s]
# 2024-02-05 15:14:19,394: Epoch 3 average validation loss: 1.00306 -- Median validation metrics: avg_loss: 1.00306, NSE: 0.08486
# # Epoch 4: 100%|██████████| 4/4 [00:00<00:00,  9.95it/s, Loss: 0.2735]
# 2024-02-05 15:14:19,799: Epoch 4 average loss: avg_loss: 0.30022, avg_total_loss: 0.30022
# # Epoch 5: 100%|██████████| 4/4 [00:00<00:00, 11.36it/s, Loss: 0.3373]
# 2024-02-05 15:14:20,157: Epoch 5 average loss: avg_loss: 0.31183, avg_total_loss: 0.31183
# # Epoch 6: 100%|██████████| 4/4 [00:00<00:00, 10.07it/s, Loss: 0.1555]
# 2024-02-05 15:14:20,559: Epoch 6 average loss: avg_loss: 0.26954, avg_total_loss: 0.26954
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 24.51it/s]
# 2024-02-05 15:14:20,807: Epoch 6 average validation loss: 1.16596 -- Median validation metrics: avg_loss: 1.16596, NSE: -0.06894
# # Epoch 7: 100%|██████████| 4/4 [00:00<00:00,  9.63it/s, Loss: 0.2351]
# 2024-02-05 15:14:21,228: Epoch 7 average loss: avg_loss: 0.27163, avg_total_loss: 0.27163
# # Epoch 8: 100%|██████████| 4/4 [00:00<00:00, 10.31it/s, Loss: 0.2703]
# 2024-02-05 15:14:21,619: Epoch 8 average loss: avg_loss: 0.27686, avg_total_loss: 0.27686
# # Epoch 9: 100%|██████████| 4/4 [00:00<00:00, 10.37it/s, Loss: 0.2769]
# 2024-02-05 15:14:22,009: Epoch 9 average loss: avg_loss: 0.27171, avg_total_loss: 0.27171
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.61it/s]
# 2024-02-05 15:14:22,261: Epoch 9 average validation loss: 1.12689 -- Median validation metrics: avg_loss: 1.12689, NSE: -0.03194
# # Epoch 10: 100%|██████████| 4/4 [00:00<00:00,  9.99it/s, Loss: 0.2027]
# 2024-02-05 15:14:22,664: Epoch 10 average loss: avg_loss: 0.26117, avg_total_loss: 0.26117
# # Epoch 11: 100%|██████████| 4/4 [00:00<00:00, 10.62it/s, Loss: 0.3061]
# 2024-02-05 15:14:23,048: Epoch 11 average loss: avg_loss: 0.27499, avg_total_loss: 0.27499
# # Epoch 12: 100%|██████████| 4/4 [00:00<00:00, 10.46it/s, Loss: 0.1668]
# 2024-02-05 15:14:23,434: Epoch 12 average loss: avg_loss: 0.26801, avg_total_loss: 0.26801
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 25.47it/s]
# 2024-02-05 15:14:23,679: Epoch 12 average validation loss: 0.96558 -- Median validation metrics: avg_loss: 0.96558, NSE: 0.11496
# # Epoch 13: 100%|██████████| 4/4 [00:00<00:00, 10.19it/s, Loss: 0.3368]
# 2024-02-05 15:14:24,074: Epoch 13 average loss: avg_loss: 0.31307, avg_total_loss: 0.31307
# # Epoch 14: 100%|██████████| 4/4 [00:00<00:00, 11.15it/s, Loss: 0.2869]
# 2024-02-05 15:14:24,439: Epoch 14 average loss: avg_loss: 0.25054, avg_total_loss: 0.25054
# # Epoch 15: 100%|██████████| 4/4 [00:00<00:00, 10.45it/s, Loss: 0.2527]
# 2024-02-05 15:14:24,825: Epoch 15 average loss: avg_loss: 0.24938, avg_total_loss: 0.24938
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.92it/s]
# 2024-02-05 15:14:25,076: Epoch 15 average validation loss: 0.95458 -- Median validation metrics: avg_loss: 0.95458, NSE: 0.14190
# # Epoch 16: 100%|██████████| 4/4 [00:00<00:00, 10.64it/s, Loss: 0.2150]
# 2024-02-05 15:14:25,455: Epoch 16 average loss: avg_loss: 0.24746, avg_total_loss: 0.24746
# # Epoch 17: 100%|██████████| 4/4 [00:00<00:00,  9.97it/s, Loss: 0.1384]
# 2024-02-05 15:14:25,859: Epoch 17 average loss: avg_loss: 0.23065, avg_total_loss: 0.23065
# # Epoch 18: 100%|██████████| 4/4 [00:00<00:00, 10.76it/s, Loss: 0.1412]
# 2024-02-05 15:14:26,234: Epoch 18 average loss: avg_loss: 0.20981, avg_total_loss: 0.20981
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 26.29it/s]
# 2024-02-05 15:14:26,483: Epoch 18 average validation loss: 0.91008 -- Median validation metrics: avg_loss: 0.91008, NSE: 0.15961
# # Epoch 19: 100%|██████████| 4/4 [00:00<00:00,  9.44it/s, Loss: 0.1340]
# 2024-02-05 15:14:26,909: Epoch 19 average loss: avg_loss: 0.21517, avg_total_loss: 0.21517
# # Epoch 20: 100%|██████████| 4/4 [00:00<00:00,  9.86it/s, Loss: 0.1535]
# 2024-02-05 15:14:27,321: Epoch 20 average loss: avg_loss: 0.19004, avg_total_loss: 0.19004
# # Epoch 21: 100%|██████████| 4/4 [00:00<00:00,  8.68it/s, Loss: 0.2628]
# 2024-02-05 15:14:27,786: Epoch 21 average loss: avg_loss: 0.20896, avg_total_loss: 0.20896
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 25.05it/s]
# 2024-02-05 15:14:28,051: Epoch 21 average validation loss: 0.92283 -- Median validation metrics: avg_loss: 0.92283, NSE: 0.15759
# # Epoch 22: 100%|██████████| 4/4 [00:00<00:00,  8.81it/s, Loss: 0.3219]
# 2024-02-05 15:14:28,507: Epoch 22 average loss: avg_loss: 0.23733, avg_total_loss: 0.23733
# # Epoch 23: 100%|██████████| 4/4 [00:00<00:00,  9.57it/s, Loss: 0.1330]
# 2024-02-05 15:14:28,928: Epoch 23 average loss: avg_loss: 0.18040, avg_total_loss: 0.18040
# # Epoch 24: 100%|██████████| 4/4 [00:00<00:00,  9.42it/s, Loss: 0.2221]
# 2024-02-05 15:14:29,356: Epoch 24 average loss: avg_loss: 0.18746, avg_total_loss: 0.18746
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.86it/s]
# 2024-02-05 15:14:29,608: Epoch 24 average validation loss: 0.97652 -- Median validation metrics: avg_loss: 0.97652, NSE: 0.11151
# # Epoch 25: 100%|██████████| 4/4 [00:00<00:00,  9.13it/s, Loss: 0.1780]
# 2024-02-05 15:14:30,048: Epoch 25 average loss: avg_loss: 0.16884, avg_total_loss: 0.16884
# # Epoch 26: 100%|██████████| 4/4 [00:00<00:00,  9.66it/s, Loss: 0.3265]
# 2024-02-05 15:14:30,467: Epoch 26 average loss: avg_loss: 0.20736, avg_total_loss: 0.20736
# # Epoch 27: 100%|██████████| 4/4 [00:00<00:00,  8.76it/s, Loss: 0.1746]
# 2024-02-05 15:14:30,927: Epoch 27 average loss: avg_loss: 0.17576, avg_total_loss: 0.17576
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 22.29it/s]
# 2024-02-05 15:14:31,186: Epoch 27 average validation loss: 0.93551 -- Median validation metrics: avg_loss: 0.93551, NSE: 0.13237
# # Epoch 28: 100%|██████████| 4/4 [00:00<00:00,  8.97it/s, Loss: 0.0852]
# 2024-02-05 15:14:31,634: Epoch 28 average loss: avg_loss: 0.16786, avg_total_loss: 0.16786
# # Epoch 29: 100%|██████████| 4/4 [00:00<00:00,  9.52it/s, Loss: 0.1334]
# 2024-02-05 15:14:32,058: Epoch 29 average loss: avg_loss: 0.16307, avg_total_loss: 0.16307
# 2024-02-05 15:14:32,060: Setting learning rate to 0.005
# # Epoch 30: 100%|██████████| 4/4 [00:00<00:00,  9.46it/s, Loss: 0.1531]
# 2024-02-05 15:14:32,485: Epoch 30 average loss: avg_loss: 0.15568, avg_total_loss: 0.15568
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 22.60it/s]
# 2024-02-05 15:14:32,764: Epoch 30 average validation loss: 0.76949 -- Median validation metrics: avg_loss: 0.76949, NSE: 0.26086
# # Epoch 31: 100%|██████████| 4/4 [00:00<00:00,  9.39it/s, Loss: 0.1221]
# 2024-02-05 15:14:33,192: Epoch 31 average loss: avg_loss: 0.13900, avg_total_loss: 0.13900
# # Epoch 32: 100%|██████████| 4/4 [00:00<00:00,  9.60it/s, Loss: 0.3097]
# 2024-02-05 15:14:33,613: Epoch 32 average loss: avg_loss: 0.18775, avg_total_loss: 0.18775
# # Epoch 33: 100%|██████████| 4/4 [00:00<00:00,  9.24it/s, Loss: 0.1696]
# 2024-02-05 15:14:34,050: Epoch 33 average loss: avg_loss: 0.15002, avg_total_loss: 0.15002
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.78it/s]
# 2024-02-05 15:14:34,326: Epoch 33 average validation loss: 0.82045 -- Median validation metrics: avg_loss: 0.82045, NSE: 0.21725
# # Epoch 34: 100%|██████████| 4/4 [00:00<00:00,  8.83it/s, Loss: 0.0895]
# 2024-02-05 15:14:34,781: Epoch 34 average loss: avg_loss: 0.12646, avg_total_loss: 0.12646
# # Epoch 35: 100%|██████████| 4/4 [00:00<00:00,  8.30it/s, Loss: 0.2187]
# 2024-02-05 15:14:35,268: Epoch 35 average loss: avg_loss: 0.13330, avg_total_loss: 0.13330
# # Epoch 36: 100%|██████████| 4/4 [00:00<00:00,  9.03it/s, Loss: 0.0773]
# 2024-02-05 15:14:35,714: Epoch 36 average loss: avg_loss: 0.10876, avg_total_loss: 0.10876
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.15it/s]
# 2024-02-05 15:14:35,989: Epoch 36 average validation loss: 0.77781 -- Median validation metrics: avg_loss: 0.77781, NSE: 0.25985
# # Epoch 37: 100%|██████████| 4/4 [00:00<00:00,  9.99it/s, Loss: 0.1211]
# 2024-02-05 15:14:36,392: Epoch 37 average loss: avg_loss: 0.12102, avg_total_loss: 0.12102
# # Epoch 38: 100%|██████████| 4/4 [00:00<00:00,  8.79it/s, Loss: 0.2145]
# 2024-02-05 15:14:36,851: Epoch 38 average loss: avg_loss: 0.13604, avg_total_loss: 0.13604
# # Epoch 39: 100%|██████████| 4/4 [00:00<00:00,  9.19it/s, Loss: 0.1046]
# 2024-02-05 15:14:37,290: Epoch 39 average loss: avg_loss: 0.11713, avg_total_loss: 0.11713
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.03it/s]
# 2024-02-05 15:14:37,558: Epoch 39 average validation loss: 0.88642 -- Median validation metrics: avg_loss: 0.88642, NSE: 0.16283
# 2024-02-05 15:14:37,559: Setting learning rate to 0.001
# # Epoch 40: 100%|██████████| 4/4 [00:00<00:00,  8.45it/s, Loss: 0.0915]
# 2024-02-05 15:14:38,034: Epoch 40 average loss: avg_loss: 0.11062, avg_total_loss: 0.11062
# # Epoch 41: 100%|██████████| 4/4 [00:00<00:00,  9.10it/s, Loss: 0.1286]
# 2024-02-05 15:14:38,478: Epoch 41 average loss: avg_loss: 0.11921, avg_total_loss: 0.11921
# # Epoch 42: 100%|██████████| 4/4 [00:00<00:00,  8.46it/s, Loss: 0.0847]
# 2024-02-05 15:14:38,954: Epoch 42 average loss: avg_loss: 0.12477, avg_total_loss: 0.12477
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.72it/s]
# 2024-02-05 15:14:39,230: Epoch 42 average validation loss: 0.84788 -- Median validation metrics: avg_loss: 0.84788, NSE: 0.20543
# # Epoch 43: 100%|██████████| 4/4 [00:00<00:00,  9.26it/s, Loss: 0.1087]
# 2024-02-05 15:14:39,664: Epoch 43 average loss: avg_loss: 0.12154, avg_total_loss: 0.12154
# # Epoch 44: 100%|██████████| 4/4 [00:00<00:00,  8.85it/s, Loss: 0.0680]
# 2024-02-05 15:14:40,119: Epoch 44 average loss: avg_loss: 0.10070, avg_total_loss: 0.10070
# # Epoch 45: 100%|██████████| 4/4 [00:00<00:00,  9.32it/s, Loss: 0.1185]
# 2024-02-05 15:14:40,552: Epoch 45 average loss: avg_loss: 0.10943, avg_total_loss: 0.10943
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 22.02it/s]
# 2024-02-05 15:14:40,955: Epoch 45 average validation loss: 0.84672 -- Median validation metrics: avg_loss: 0.84672, NSE: 0.20429
# # Epoch 46: 100%|██████████| 4/4 [00:00<00:00,  8.48it/s, Loss: 0.1507]
# 2024-02-05 15:14:41,430: Epoch 46 average loss: avg_loss: 0.11309, avg_total_loss: 0.11309
# # Epoch 47: 100%|██████████| 4/4 [00:00<00:00,  8.12it/s, Loss: 0.1486]
# 2024-02-05 15:14:41,928: Epoch 47 average loss: avg_loss: 0.10540, avg_total_loss: 0.10540
# # Epoch 48: 100%|██████████| 4/4 [00:00<00:00,  9.37it/s, Loss: 0.0815]
# 2024-02-05 15:14:42,359: Epoch 48 average loss: avg_loss: 0.10766, avg_total_loss: 0.10766
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.25it/s]
# 2024-02-05 15:14:42,640: Epoch 48 average validation loss: 0.86427 -- Median validation metrics: avg_loss: 0.86427, NSE: 0.18777
# # Epoch 49: 100%|██████████| 4/4 [00:00<00:00,  8.28it/s, Loss: 0.0995]
# 2024-02-05 15:14:43,126: Epoch 49 average loss: avg_loss: 0.11223, avg_total_loss: 0.11223
# # Epoch 50: 100%|██████████| 4/4 [00:00<00:00,  9.14it/s, Loss: 0.1021]
# 2024-02-05 15:14:43,567: Epoch 50 average loss: avg_loss: 0.10715, avg_total_loss: 0.10715

# %% [markdown]
# ### Evaluate run on test set
# The run directory that needs to be specified for evaluation is printed in the output log above. Since the folder name is created dynamically (including the date and time of the start of the run) you will need to change the `run_dir` argument according to your local directory name. By default, it will use the same device as during the training process.

# %%
run_dir = Path("runs/test_run_cl_0502_151417")
eval_run(run_dir=run_dir, period="test")
# Out:
# 2024-02-05 15:15:11,145: Using the model weights from runs/test_run_cl_0502_151417/model_epoch050.pt
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00, 12.14it/s]
# 2024-02-05 15:15:11,232: Stored metrics at runs/test_run_cl_0502_151417/test/model_epoch050/test_metrics.csv
# 2024-02-05 15:15:11,233: Stored results at runs/test_run_cl_0502_151417/test/model_epoch050/test_results.p

# %% [markdown]
# ### Load and inspect model predictions
# Next, we load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions. In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.

# %%
with open(run_dir / "test" / "model_epoch050" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
    
results.keys()
# Out:
# dict_keys(['12872001'])

# %% [markdown]
# The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
results['12872001']['1D']['xr']
# Out:
# <xarray.Dataset>
# Dimensions:    (date: 366, time_step: 1)
# Coordinates:
#   * date       (date) datetime64[ns] 2007-01-12 2007-01-13 ... 2008-01-12
#   * time_step  (time_step) int64 0
# Data variables:
#     q_mm_obs   (date, time_step) float32 0.1901 0.1814 0.1755 ... 0.2369 0.2355
#     q_mm_sim   (date, time_step) float32 0.2148 0.1997 0.1777 ... 0.143 0.1163

# %% [markdown]
# Let's plot the model predictions vs. the observations

# %%
# extract observations and simulations
qobs = results['12872001']['1D']['xr']['q_mm_obs']
qsim = results['12872001']['1D']['xr']['q_mm_sim']

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("q_mm")
ax.set_title(f"Test period - NSE {results['12872001']['1D']['NSE']:.3f}")
# Out:
# Text(0.5, 1.0, 'Test period - NSE 0.313')

# %% [markdown]
# Next, we are going to compute all metrics that are implemented in the NeuralHydrology package. You will find additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.313
# MSE: 0.090
# RMSE: 0.299
# KGE: 0.290
# Alpha-NSE: 0.426
# Beta-KGE: 0.710
# Beta-NSE: -0.320
# Pearson-r: 0.700
# FHV: -54.025
# FMS: -26.894
# FLV: -158.786
# Peak-Timing: nan
# Peak-MAPE: 75.188
# /home/sngrjohn/GitLab/neuralhydrology/neuralhydrology/datautils/utils.py:274: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/sngrjohn/GitLab/neuralhydrology/neuralhydrology/datautils/utils.py:315: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
