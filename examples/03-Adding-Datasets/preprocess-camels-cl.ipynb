# %%
import numpy as np
import pandas as pd
import xarray
from tqdm import tqdm
import os
from pathlib import Path

from neuralhydrology.datasetzoo.camelscl import preprocess_camels_cl_dataset
from neuralhydrology.datasetzoo.camelscl import load_camels_cl_attributes
from neuralhydrology.datasetzoo.camelscl import load_camels_cl_timeseries
# Out:
# /tmp/ipykernel_2974531/907436394.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
os.getcwd()
# Out:
# '/home/sngrjohn/GitLab/neuralhydrology/examples/03-Adding-Datasets'

# %%
# set wd to wkspce root
os.chdir('../../')

# %%
# set datadir to Camels-cl input
data_dir = Path('./data/CAMELS_CL_v202201')

# %%
preprocess_camels_cl_dataset(data_dir)
# Out:
# ...
# Creating per-basin dataframes and saving to disk: 100%|██████████| 519/519 [00:52<00:00,  9.97it/s]
# Finished processing the CAMELS CL data set. Resulting per-basin csv files have been stored at data/CAMELS_CL_v202201/preprocessed
