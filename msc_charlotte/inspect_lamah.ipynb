# %%
from neuralhydrology.datasetzoo.lamah import load_lamah_attributes
from neuralhydrology.datasetzoo.lamah import load_lamah_forcing
from neuralhydrology.datasetzoo.lamah import load_lamah_discharge
from neuralhydrology.datasetzoo.lamah import LamaH

from pathlib import Path

# %%
data_dir = Path('../data/1_LamaH-CE_daily_hourly')

# %%
df_attributes = load_lamah_attributes(data_dir, 'lamah_a', basins=['1', '2', '3'])

# %%
df_attributes.columns
# Out:
# Index(['area_calc', 'elev_mean', 'elev_med', 'elev_std', 'elev_ran',
#        'slope_mean', 'mvert_dist', 'mvert_ang', 'elon_ratio', 'strm_dens',
#        'p_mean', 'et0_mean', 'eta_mean', 'arid_1', 'arid_2', 'p_season',
#        'frac_snow', 'hi_prec_fr', 'hi_prec_du', 'hi_prec_ti', 'lo_prec_fr',
#        'lo_prec_du', 'lo_prec_ti', 'lc_dom', 'agr_fra', 'bare_fra',
#        'forest_fra', 'glac_fra', 'lake_fra', 'urban_fra', 'lai_max',
#        'lai_diff', 'ndvi_max', 'ndvi_min', 'gvf_max', 'gvf_diff', 'bedrk_dep',
#        'root_dep', 'soil_poros', 'soil_condu', 'soil_tawc', 'sand_fra',
#        'silt_fra', 'clay_fra', 'grav_fra', 'oc_fra', 'gc_dom', 'gc_ig_fra',
#        'gc_mt_fra', 'gc_pa_fra', 'gc_pb_fra', 'gc_pi_fra', 'gc_py_fra',
#        'gc_sc_fra', 'gc_sm_fra', 'gc_ss_fra', 'gc_su_fra', 'gc_va_fra',
#        'gc_vb_fra', 'gc_wb_fra', 'geol_perme', 'geol_poros', 'govnr', 'name',
#        'river', 'area_gov', 'elev', 'lon', 'lat', 'country', 'fedstate',
# ...

# %%
df_discharge = load_lamah_discharge(data_dir, basin='1')

# %%
df_discharge['qobs'].plot()
# Out:
# <Axes: xlabel='date'>

# %%
df_forcings = load_lamah_forcing(data_dir, sub_dataset='lamah_a', basin='1')

# %%
df_forcings.columns
# Out:
# Index(['DOY', '2m_temp_max', '2m_temp_mean', '2m_temp_min', '2m_dp_temp_max',
#        '2m_dp_temp_mean', '2m_dp_temp_min', '10m_wind_u', '10m_wind_v',
#        'fcst_alb', 'lai_high_veg', 'lai_low_veg', 'swe',
#        'surf_net_solar_rad_max', 'surf_net_solar_rad_mean',
#        'surf_net_therm_rad_max', 'surf_net_therm_rad_mean', 'surf_press',
#        'total_et', 'prec', 'volsw_123', 'volsw_4'],
#       dtype='object')
