# %%
# Imports
from pathlib import Path
import matplotlib as mpl
import pickle
import numpy as np
import matplotlib.pyplot as plt

import pandas as pd
import torch
from neuralhydrology.nh_run import start_run, eval_run, finetune

# %%
mpl.rcParams["grid.color"] = "#eeeeee"
mpl.rcParams["grid.linewidth"] = 0.5
mpl.rcParams["axes.spines.right"] = False
mpl.rcParams["axes.spines.top"] = False
mpl.rcParams['font.family'] = 'Times New Roman'
mpl.rcParams.update({'font.size': 11})

# %% [markdown]
# ### Pretraining

# %%
# by default we assume that you have at least one CUDA-capable NVIDIA GPU
if torch.cuda.is_available():
    start_run(config_file=Path("750_basins.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("750_basins.yml"), gpu=-1)
# Out:
# 2024-09-26 17:06:36,523: Logging to /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/output.log initialized.
# 2024-09-26 17:06:36,524: ### Folder structure created at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636
# 2024-09-26 17:06:36,524: ### Run configurations for cudalstm_750_basins
# 2024-09-26 17:06:36,524: experiment_name: cudalstm_750_basins
# 2024-09-26 17:06:36,525: train_basin_file: 750_basins_list.txt
# 2024-09-26 17:06:36,525: validation_basin_file: 750_basins_list.txt
# 2024-09-26 17:06:36,525: test_basin_file: 750_basins_list.txt
# 2024-09-26 17:06:36,525: train_start_date: 1951-01-01 00:00:00
# 2024-09-26 17:06:36,526: train_end_date: 2015-09-30 00:00:00
# 2024-09-26 17:06:36,526: validation_start_date: 2015-10-01 00:00:00
# 2024-09-26 17:06:36,526: validation_end_date: 2018-09-30 00:00:00
# 2024-09-26 17:06:36,527: test_start_date: 2018-10-01 00:00:00
# 2024-09-26 17:06:36,527: test_end_date: 2020-12-31 00:00:00
# 2024-09-26 17:06:36,527: seed: 32
# 2024-09-26 17:06:36,527: device: cuda:0
# 2024-09-26 17:06:36,527: validate_every: 4
# 2024-09-26 17:06:36,528: validate_n_random_basins: 750
# 2024-09-26 17:06:36,528: metrics: ['NSE']
# 2024-09-26 17:06:36,528: model: cudalstm
# 2024-09-26 17:06:36,529: head: cmal
# 2024-09-26 17:06:36,529: n_distributions: 3
# 2024-09-26 17:06:36,529: n_samples: 1000
# 2024-09-26 17:06:36,529: negative_sample_handling: clip
# 2024-09-26 17:06:36,530: num_layers: 1
# 2024-09-26 17:06:36,530: hidden_size: 256
# 2024-09-26 17:06:36,530: initial_forget_bias: 3
# 2024-09-26 17:06:36,531: target_noise_std: 0.1
# 2024-09-26 17:06:36,531: output_dropout: 0.4
# 2024-09-26 17:06:36,531: optimizer: Adam
# 2024-09-26 17:06:36,531: loss: CMALLoss
# 2024-09-26 17:06:36,532: learning_rate: {0: 0.001, 5: 0.0005, 10: 0.0001}
# 2024-09-26 17:06:36,532: batch_size: 256
# 2024-09-26 17:06:36,532: epochs: 15
# 2024-09-26 17:06:36,532: clip_gradient_norm: 1
# 2024-09-26 17:06:36,533: predict_last_n: 1
# 2024-09-26 17:06:36,533: seq_length: 365
# 2024-09-26 17:06:36,533: num_workers: 8
# 2024-09-26 17:06:36,533: log_interval: 5
# 2024-09-26 17:06:36,534: log_tensorboard: True
# 2024-09-26 17:06:36,534: save_weights_every: 1
# 2024-09-26 17:06:36,534: save_validation_results: True
# 2024-09-26 17:06:36,535: dataset: camels_de
# 2024-09-26 17:06:36,535: data_dir: ../../../data/camels_de
# 2024-09-26 17:06:36,535: dynamic_inputs: ['precipitation_mean', 'precipitation_min', 'precipitation_max', 'humidity_mean', 'humidity_min', 'humidity_max', 'radiation_global_mean', 'radiation_global_min', 'radiation_global_max', 'temperature_mean', 'temperature_min', 'temperature_max']
# 2024-09-26 17:06:36,535: target_variables: ['discharge_vol']
# 2024-09-26 17:06:36,535: static_attributes: ['p_mean', 'p_seasonality', 'frac_snow', 'high_prec_freq', 'high_prec_dur', 'low_prec_freq', 'low_prec_dur', 'aquitard_perc', 'aquifer_perc', 'aquifer_aquitard_mixed_perc', 'waterbody_perc', 'artificial_surfaces_perc', 'agricultural_areas_perc', 'forests_and_seminatural_areas_perc', 'wetlands_perc', 'water_bodies_perc', 'q_mean', 'runoff_ratio', 'slope_fdc', 'hfd_mean']
# 2024-09-26 17:06:36,536: number_of_basins: 750
# 2024-09-26 17:06:36,536: run_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636
# 2024-09-26 17:06:36,536: train_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/train_data
# 2024-09-26 17:06:36,536: img_log_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/img_log
# 2024-09-26 17:06:36,547: ### Device cuda:0 will be used for training
# 2024-09-26 17:06:36,616: Loading basin data into xarray data set.
# 100%|██████████| 750/750 [00:22<00:00, 34.00it/s]
# 2024-09-26 17:07:00,069: Create lookup table and convert to pytorch tensor
# 100%|██████████| 750/750 [01:20<00:00,  9.36it/s]
# # Epoch 1: 100%|██████████| 43303/43303 [20:04<00:00, 35.95it/s, Loss: -2.1471]
# 2024-09-26 17:28:25,782: Epoch 1 average loss: avg_loss: -2.02216, avg_total_loss: -2.02216
# # Epoch 2: 100%|██████████| 43303/43303 [20:01<00:00, 36.04it/s, Loss: -2.0540]
# 2024-09-26 17:48:27,422: Epoch 2 average loss: avg_loss: -2.24680, avg_total_loss: -2.24680
# # Epoch 3: 100%|██████████| 43303/43303 [20:00<00:00, 36.07it/s, Loss: -2.4843]
# 2024-09-26 18:08:28,001: Epoch 3 average loss: avg_loss: -2.29858, avg_total_loss: -2.29858
# # Epoch 4: 100%|██████████| 43303/43303 [20:03<00:00, 35.98it/s, Loss: -2.4735]
# 2024-09-26 18:28:31,649: Epoch 4 average loss: avg_loss: -2.32886, avg_total_loss: -2.32886
# # Validation: 100%|██████████| 750/750 [11:37<00:00,  1.07it/s]
# 2024-09-26 18:40:09,522: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/validation/model_epoch004/validation_metrics.csv
# 2024-09-26 18:40:11,170: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/validation/model_epoch004/validation_results.p
# 2024-09-26 18:40:11,177: Epoch 4 average validation loss: -2.63333 -- Median validation metrics: avg_loss: -2.63333, NSE: 0.85189
# 2024-09-26 18:40:11,177: Setting learning rate to 0.0005
# # Epoch 5: 100%|██████████| 43303/43303 [20:23<00:00, 35.38it/s, Loss: -2.2824]
# 2024-09-26 19:00:35,046: Epoch 5 average loss: avg_loss: -2.40237, avg_total_loss: -2.40237
# # Epoch 6: 100%|██████████| 43303/43303 [20:25<00:00, 35.34it/s, Loss: -2.6111]
# 2024-09-26 19:21:00,520: Epoch 6 average loss: avg_loss: -2.42288, avg_total_loss: -2.42288
# # Epoch 7: 100%|██████████| 43303/43303 [20:19<00:00, 35.51it/s, Loss: -2.3062]
# 2024-09-26 19:41:19,890: Epoch 7 average loss: avg_loss: -2.43684, avg_total_loss: -2.43684
# # Epoch 8: 100%|██████████| 43303/43303 [20:19<00:00, 35.52it/s, Loss: -2.5263]
# 2024-09-26 20:01:39,085: Epoch 8 average loss: avg_loss: -2.44837, avg_total_loss: -2.44837
# # Validation: 100%|██████████| 750/750 [11:30<00:00,  1.09it/s]
# 2024-09-26 20:13:09,806: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/validation/model_epoch008/validation_metrics.csv
# 2024-09-26 20:13:11,462: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/validation/model_epoch008/validation_results.p
# 2024-09-26 20:13:11,468: Epoch 8 average validation loss: -2.64529 -- Median validation metrics: avg_loss: -2.64529, NSE: 0.82895
# # Epoch 9: 100%|██████████| 43303/43303 [20:28<00:00, 35.25it/s, Loss: -2.8134]
# 2024-09-26 20:33:39,755: Epoch 9 average loss: avg_loss: -2.45762, avg_total_loss: -2.45762
# 2024-09-26 20:33:39,759: Setting learning rate to 0.0001
# # Epoch 10: 100%|██████████| 43303/43303 [20:22<00:00, 35.41it/s, Loss: -2.6094]
# 2024-09-26 20:54:02,653: Epoch 10 average loss: avg_loss: -2.51260, avg_total_loss: -2.51260
# # Epoch 11: 100%|██████████| 43303/43303 [20:22<00:00, 35.43it/s, Loss: -2.4822]
# 2024-09-26 21:14:24,898: Epoch 11 average loss: avg_loss: -2.52152, avg_total_loss: -2.52152
# # Epoch 12: 100%|██████████| 43303/43303 [20:31<00:00, 35.16it/s, Loss: -2.5532]
# 2024-09-26 21:34:56,633: Epoch 12 average loss: avg_loss: -2.52634, avg_total_loss: -2.52634
# # Validation: 100%|██████████| 750/750 [11:23<00:00,  1.10it/s]
# 2024-09-26 21:46:19,897: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/validation/model_epoch012/validation_metrics.csv
# 2024-09-26 21:46:21,571: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/validation/model_epoch012/validation_results.p
# 2024-09-26 21:46:21,576: Epoch 12 average validation loss: -2.66589 -- Median validation metrics: avg_loss: -2.66589, NSE: 0.84935
# # Epoch 13: 100%|██████████| 43303/43303 [20:24<00:00, 35.37it/s, Loss: -2.6847]
# 2024-09-26 22:06:45,992: Epoch 13 average loss: avg_loss: -2.53059, avg_total_loss: -2.53059
# # Epoch 14: 100%|██████████| 43303/43303 [20:38<00:00, 34.97it/s, Loss: -2.5710]
# 2024-09-26 22:27:24,445: Epoch 14 average loss: avg_loss: -2.53414, avg_total_loss: -2.53414
# # Epoch 15: 100%|██████████| 43303/43303 [20:33<00:00, 35.12it/s, Loss: -2.5609]
# 2024-09-26 22:47:57,620: Epoch 15 average loss: avg_loss: -2.53726, avg_total_loss: -2.53726

# %%
# Load validation results from the last epoch
run_dir = Path("runs/cudalstm_750_basins_2609_170636")
df = pd.read_csv(run_dir / "validation" / "model_epoch012" / "validation_metrics.csv", dtype={'basin': str})
df = df.set_index('basin')

# Compute the median NSE from all basins, where discharge observations are available for that period
print(f"Median NSE of the validation period {df['NSE'].median():.3f}")

# Select the basin of choice:
basin = 'DE4'
print(f"Selected basin: {basin} with an NSE of {df.loc[df.index == basin, 'NSE'].values[0]:.3f}")
# Out:
# Median NSE of the validation period 0.849
# Selected basin: DE4 with an NSE of 0.824

# %%
regional_dir = Path("runs/cudalstm_750_basins_2609_170636")
eval_run(regional_dir, period="test")
# Out:
# # Evaluation: 100%|██████████| 750/750 [12:26<00:00,  1.01it/s]

# %%
# Load Pretraining results for comparison
multi_basin_dir = Path("runs/cudalstm_750_basins_2609_170636")
with open(multi_basin_dir / "test" / "model_epoch015" / "test_results.p", "rb") as fp:
    results_multi_basin = pickle.load(fp)

# Extract observations and simulations
qobs_multi_basin = results_multi_basin['DE4']['1D']['xr']['discharge_vol_obs']
qsim_multi_basin = results_multi_basin['DE4']['1D']['xr']['discharge_vol_sim']

# %% [markdown]
# ### Finetuning

# %%
basin = 'DE4'
# Add the path to the pre-trained model to the finetune config
with open("finetune.yml", "a") as fp:
    fp.write(f"\nbase_run_dir: {run_dir.absolute()}")
    
# Create a basin file with the basin we selected above
with open("finetune_basin.txt", "w") as fp:
    fp.write(basin)

# %%
finetune(Path("finetune.yml"))
# Out:
# 2024-09-27 09:58:26,903: Logging to /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/output.log initialized.
# 2024-09-27 09:58:26,903: ### Folder structure created at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826
# 2024-09-27 09:58:26,903: ### Start finetuning with pretrained model stored in /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636
# 2024-09-27 09:58:26,903: ### Run configurations for cudalstm_750_basins_finetuned
# 2024-09-27 09:58:26,903: batch_size: 256
# 2024-09-27 09:58:26,903: clip_gradient_norm: 1
# 2024-09-27 09:58:26,904: commit_hash: dd0f70b
# 2024-09-27 09:58:26,904: data_dir: ../../../data/camels_de
# 2024-09-27 09:58:26,904: dataset: camels_de
# 2024-09-27 09:58:26,904: device: cuda:0
# 2024-09-27 09:58:26,904: dynamic_inputs: ['precipitation_mean', 'precipitation_min', 'precipitation_max', 'humidity_mean', 'humidity_min', 'humidity_max', 'radiation_global_mean', 'radiation_global_min', 'radiation_global_max', 'temperature_mean', 'temperature_min', 'temperature_max']
# 2024-09-27 09:58:26,904: epochs: 20
# 2024-09-27 09:58:26,904: experiment_name: cudalstm_750_basins_finetuned
# 2024-09-27 09:58:26,905: head: cmal
# 2024-09-27 09:58:26,905: hidden_size: 256
# 2024-09-27 09:58:26,905: img_log_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/img_log
# 2024-09-27 09:58:26,905: initial_forget_bias: 3
# 2024-09-27 09:58:26,905: learning_rate: 0.0005
# 2024-09-27 09:58:26,905: log_interval: 5
# 2024-09-27 09:58:26,905: log_tensorboard: True
# 2024-09-27 09:58:26,905: loss: CMALLoss
# 2024-09-27 09:58:26,905: metrics: ['NSE']
# 2024-09-27 09:58:26,905: model: cudalstm
# 2024-09-27 09:58:26,906: n_distributions: 3
# 2024-09-27 09:58:26,906: n_samples: 1000
# 2024-09-27 09:58:26,906: negative_sample_handling: clip
# 2024-09-27 09:58:26,907: num_layers: 1
# 2024-09-27 09:58:26,907: num_workers: 8
# 2024-09-27 09:58:26,907: number_of_basins: 1
# 2024-09-27 09:58:26,907: optimizer: Adam
# 2024-09-27 09:58:26,907: output_dropout: 0.4
# 2024-09-27 09:58:26,907: package_version: 1.11.0
# 2024-09-27 09:58:26,908: predict_last_n: 1
# 2024-09-27 09:58:26,908: run_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826
# 2024-09-27 09:58:26,908: save_validation_results: True
# 2024-09-27 09:58:26,908: save_weights_every: 1
# 2024-09-27 09:58:26,908: seed: 32
# 2024-09-27 09:58:26,909: seq_length: 365
# 2024-09-27 09:58:26,909: static_attributes: ['p_mean', 'p_seasonality', 'frac_snow', 'high_prec_freq', 'high_prec_dur', 'low_prec_freq', 'low_prec_dur', 'aquitard_perc', 'aquifer_perc', 'aquifer_aquitard_mixed_perc', 'waterbody_perc', 'artificial_surfaces_perc', 'agricultural_areas_perc', 'forests_and_seminatural_areas_perc', 'wetlands_perc', 'water_bodies_perc', 'q_mean', 'runoff_ratio', 'slope_fdc', 'hfd_mean']
# 2024-09-27 09:58:26,909: target_noise_std: 0.1
# 2024-09-27 09:58:26,909: target_variables: ['discharge_vol']
# 2024-09-27 09:58:26,909: test_basin_file: finetune_basin.txt
# 2024-09-27 09:58:26,909: test_end_date: 2020-12-31 00:00:00
# 2024-09-27 09:58:26,909: test_start_date: 2018-10-01 00:00:00
# 2024-09-27 09:58:26,910: train_basin_file: finetune_basin.txt
# 2024-09-27 09:58:26,910: train_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/train_data
# 2024-09-27 09:58:26,910: train_end_date: 2015-09-30 00:00:00
# 2024-09-27 09:58:26,910: train_start_date: 1951-01-01 00:00:00
# 2024-09-27 09:58:26,910: validate_every: 4
# 2024-09-27 09:58:26,910: validate_n_random_basins: 750
# 2024-09-27 09:58:26,911: validation_basin_file: finetune_basin.txt
# 2024-09-27 09:58:26,911: validation_end_date: 2018-09-30 00:00:00
# 2024-09-27 09:58:26,911: validation_start_date: 2015-10-01 00:00:00
# 2024-09-27 09:58:26,911: finetune_modules: ['head', 'lstm']
# 2024-09-27 09:58:26,911: base_run_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636
# 2024-09-27 09:58:26,911: is_finetuning: True
# 2024-09-27 09:58:26,911: is_continue_training: False
# 2024-09-27 09:58:26,912: ### Device cuda:0 will be used for training
# 2024-09-27 09:58:26,936: Loading basin data into xarray data set.
# 100%|██████████| 1/1 [00:00<00:00, 32.45it/s]
# 2024-09-27 09:58:26,970: Create lookup table and convert to pytorch tensor
# 100%|██████████| 1/1 [00:00<00:00,  2.12it/s]
# 2024-09-27 09:58:27,460: Starting training from checkpoint /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_2609_170636/model_epoch015.pt
# # Epoch 1: 100%|██████████| 91/91 [00:03<00:00, 26.04it/s, Loss: -3.5707]
# 2024-09-27 09:58:30,973: Epoch 1 average loss: avg_loss: -3.41826, avg_total_loss: -3.41826
# # Epoch 2: 100%|██████████| 91/91 [00:03<00:00, 26.00it/s, Loss: -3.4556]
# 2024-09-27 09:58:34,482: Epoch 2 average loss: avg_loss: -3.45323, avg_total_loss: -3.45323
# # Epoch 3: 100%|██████████| 91/91 [00:03<00:00, 27.94it/s, Loss: -3.5739]
# 2024-09-27 09:58:37,745: Epoch 3 average loss: avg_loss: -3.50735, avg_total_loss: -3.50735
# # Epoch 4: 100%|██████████| 91/91 [00:03<00:00, 25.03it/s, Loss: -3.5051]
# 2024-09-27 09:58:41,386: Epoch 4 average loss: avg_loss: -3.51985, avg_total_loss: -3.51985
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.53s/it]
# 2024-09-27 09:58:42,927: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch004/validation_metrics.csv
# 2024-09-27 09:58:42,929: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch004/validation_results.p
# 2024-09-27 09:58:42,930: Epoch 4 average validation loss: -3.76675 -- Median validation metrics: avg_loss: -3.76675, NSE: 0.87674
# # Epoch 5: 100%|██████████| 91/91 [00:03<00:00, 27.48it/s, Loss: -3.5344]
# 2024-09-27 09:58:46,244: Epoch 5 average loss: avg_loss: -3.55300, avg_total_loss: -3.55300
# # Epoch 6: 100%|██████████| 91/91 [00:03<00:00, 28.51it/s, Loss: -3.4672]
# 2024-09-27 09:58:49,440: Epoch 6 average loss: avg_loss: -3.54686, avg_total_loss: -3.54686
# # Epoch 7: 100%|██████████| 91/91 [00:03<00:00, 28.26it/s, Loss: -3.5801]
# 2024-09-27 09:58:52,665: Epoch 7 average loss: avg_loss: -3.57670, avg_total_loss: -3.57670
# # Epoch 8: 100%|██████████| 91/91 [00:03<00:00, 27.62it/s, Loss: -3.4646]
# 2024-09-27 09:58:55,965: Epoch 8 average loss: avg_loss: -3.57901, avg_total_loss: -3.57901
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.22s/it]
# 2024-09-27 09:58:57,189: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch008/validation_metrics.csv
# 2024-09-27 09:58:57,191: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch008/validation_results.p
# 2024-09-27 09:58:57,192: Epoch 8 average validation loss: -3.53700 -- Median validation metrics: avg_loss: -3.53700, NSE: 0.89779
# # Epoch 9: 100%|██████████| 91/91 [00:03<00:00, 27.70it/s, Loss: -3.7197]
# 2024-09-27 09:59:00,480: Epoch 9 average loss: avg_loss: -3.60392, avg_total_loss: -3.60392
# # Epoch 10: 100%|██████████| 91/91 [00:03<00:00, 26.44it/s, Loss: -3.5803]
# 2024-09-27 09:59:03,927: Epoch 10 average loss: avg_loss: -3.61533, avg_total_loss: -3.61533
# # Epoch 11: 100%|██████████| 91/91 [00:03<00:00, 27.30it/s, Loss: -3.6497]
# 2024-09-27 09:59:07,268: Epoch 11 average loss: avg_loss: -3.61989, avg_total_loss: -3.61989
# # Epoch 12: 100%|██████████| 91/91 [00:03<00:00, 28.39it/s, Loss: -3.7385]
# 2024-09-27 09:59:10,479: Epoch 12 average loss: avg_loss: -3.63609, avg_total_loss: -3.63609
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.29s/it]
# 2024-09-27 09:59:11,774: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch012/validation_metrics.csv
# 2024-09-27 09:59:11,775: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch012/validation_results.p
# 2024-09-27 09:59:11,776: Epoch 12 average validation loss: -3.63174 -- Median validation metrics: avg_loss: -3.63174, NSE: 0.89926
# # Epoch 13: 100%|██████████| 91/91 [00:03<00:00, 27.32it/s, Loss: -3.6345]
# 2024-09-27 09:59:15,109: Epoch 13 average loss: avg_loss: -3.64897, avg_total_loss: -3.64897
# # Epoch 14: 100%|██████████| 91/91 [00:03<00:00, 28.06it/s, Loss: -3.7312]
# 2024-09-27 09:59:18,357: Epoch 14 average loss: avg_loss: -3.64366, avg_total_loss: -3.64366
# # Epoch 15: 100%|██████████| 91/91 [00:03<00:00, 27.57it/s, Loss: -3.6176]
# 2024-09-27 09:59:21,663: Epoch 15 average loss: avg_loss: -3.64851, avg_total_loss: -3.64851
# # Epoch 16: 100%|██████████| 91/91 [00:03<00:00, 27.58it/s, Loss: -3.6071]
# 2024-09-27 09:59:24,968: Epoch 16 average loss: avg_loss: -3.68065, avg_total_loss: -3.68065
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.19s/it]
# 2024-09-27 09:59:26,167: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch016/validation_metrics.csv
# 2024-09-27 09:59:26,168: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch016/validation_results.p
# 2024-09-27 09:59:26,169: Epoch 16 average validation loss: -3.68550 -- Median validation metrics: avg_loss: -3.68550, NSE: 0.90961
# # Epoch 17: 100%|██████████| 91/91 [00:03<00:00, 28.55it/s, Loss: -3.5639]
# 2024-09-27 09:59:29,359: Epoch 17 average loss: avg_loss: -3.66117, avg_total_loss: -3.66117
# # Epoch 18: 100%|██████████| 91/91 [00:03<00:00, 28.70it/s, Loss: -3.6725]
# 2024-09-27 09:59:32,535: Epoch 18 average loss: avg_loss: -3.67361, avg_total_loss: -3.67361
# # Epoch 19: 100%|██████████| 91/91 [00:03<00:00, 27.39it/s, Loss: -3.8729]
# 2024-09-27 09:59:35,863: Epoch 19 average loss: avg_loss: -3.67977, avg_total_loss: -3.67977
# # Epoch 20: 100%|██████████| 91/91 [00:03<00:00, 27.96it/s, Loss: -3.5909]
# 2024-09-27 09:59:39,123: Epoch 20 average loss: avg_loss: -3.68743, avg_total_loss: -3.68743
# # Validation: 100%|██████████| 1/1 [00:01<00:00,  1.41s/it]
# 2024-09-27 09:59:40,537: Stored metrics at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch020/validation_metrics.csv
# 2024-09-27 09:59:40,538: Stored results at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/multi_basin_multi_forcing/DE4_riefensbeek_soese/runs/cudalstm_750_basins_finetuned_2709_095826/validation/model_epoch020/validation_results.p
# 2024-09-27 09:59:40,539: Epoch 20 average validation loss: -3.62124 -- Median validation metrics: avg_loss: -3.62124, NSE: 0.89534

# %%
finetune_dir = Path("runs/cudalstm_750_basins_finetuned_2709_095826")
eval_run(finetune_dir, period="test")
# Out:
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  1.01it/s]

# %%
# load test results of the finetuned model
df_finetuned = pd.read_csv(finetune_dir / "test/model_epoch020/test_metrics.csv", dtype={'basin': str})
df_finetuned = df_finetuned.set_index("basin")
    
# extract basin performance
finetune_nse = df_finetuned.loc[df_finetuned.index == basin, "NSE"].values[0]
print(f"Performance after finetuning: {finetune_nse:.3f}")
# Out:
# Performance after finetuning: 0.865

# %%
with open(finetune_dir / "test" / "model_epoch020" / "test_results.p", "rb") as fp:
    results_finetuned = pickle.load(fp)
    
results_finetuned.keys()
# Extract observations and simulations
qobs_finetuned = results_finetuned['DE4']['1D']['xr']['discharge_vol_obs']
qsim_finetuned = results_finetuned['DE4']['1D']['xr']['discharge_vol_sim']

# %%
# Load Single basin results for comparison
single_basin_dir = Path("../../single_basin_multi_forcing_MDN/DE4_riefensbeek_soese/runs/single_basin_multi_forcing_mdn_1809_141256")
with open(single_basin_dir / "test" / "model_epoch075" / "test_results.p", "rb") as fp:
    results_single_basin = pickle.load(fp)
    
results_single_basin.keys()
# Extract observations and simulations
qobs_single_basin = results_single_basin['DE4']['1D']['xr']['discharge_vol_obs']
qsim_single_basin = results_single_basin['DE4']['1D']['xr']['discharge_vol_sim']

# %%
# Define the NSE calculation function
def nse(obs, sim):
    """
    Calculate Nash-Sutcliffe Efficiency (NSE) between observed and simulated data.
    
    Parameters:
    obs (np.ndarray): Observed data array of shape (823,)
    sim (np.ndarray): Simulated data array of shape (823,)
    
    Returns:
    float: NSE value
    """
    # Ensure inputs are 1D numpy arrays
    obs = np.asarray(obs).flatten()
    sim = np.asarray(sim).flatten()
    
    # Calculate numerator and denominator for NSE
    denominator = np.sum((obs - np.mean(obs))**2)
    numerator = np.sum((sim - obs)**2)
    
    # Calculate NSE
    value = 1 - numerator / denominator
    return value

# Load or assign the observed data (shape: 823 x 1)
obs_data = qobs_finetuned  # xarray.DataArray of shape (823, 1)
obs = obs_data.values.flatten()  # Convert to 1D numpy array of shape (823,)

# Load or assign the simulated data for finetuned model (shape: 823 x 1 x 7500)
sim_data_finetuned = qsim_finetuned  # xarray.DataArray of shape (823, 1, 7500)

# Load or assign the simulated data for single basin model (shape: 823 x 1 x 7500)
sim_data_single_basin = qsim_single_basin  # xarray.DataArray of shape (823, 1, 7500)

# Load or assign the simulated data for multi basin model (shape: 823 x 1 x 7500)
sim_data_multi_basin = qsim_multi_basin # xarray.DataArray of shape (823, 1, 7500)

# Number of samples (should be 7500)
num_samples = sim_data_finetuned.shape[2]

# Initialize lists to store NSE values
nse_values_finetuned = []
nse_values_single_basin = []
nse_values_multi_basin = []

# Loop over each sample to calculate NSE for finetuned model
for i in range(num_samples):
    sim_sample_finetuned = sim_data_finetuned[:, 0, i]
    nse_i_finetuned = nse(obs, sim_sample_finetuned)
    nse_values_finetuned.append(nse_i_finetuned)

# Loop over each sample to calculate NSE for single basin model
for i in range(num_samples):
    sim_sample_single_basin = sim_data_single_basin[:, 0, i]
    nse_i_single_basin = nse(obs, sim_sample_single_basin)
    nse_values_single_basin.append(nse_i_single_basin)

# Loop over each sample to calculate NSE for multi basin model
for i in range(num_samples):
    sim_sample_multi_basin = sim_data_multi_basin[:, 0, i]
    nse_i_multi_basin = nse(obs, sim_sample_multi_basin)
    nse_values_multi_basin.append(nse_i_multi_basin)

# Convert the lists of NSE values to numpy arrays
nse_values_finetuned = np.array(nse_values_finetuned)
nse_values_single_basin = np.array(nse_values_single_basin)
nse_values_multi_basin = np.array(nse_values_multi_basin)

# Sort the NSE values in ascending order
nse_sorted_finetuned = np.sort(nse_values_finetuned)
nse_sorted_single_basin = np.sort(nse_values_single_basin)
nse_sorted_multi_basin = np.sort(nse_values_multi_basin)

# Calculate cumulative probabilities for the ECDF
cum_probs_finetuned = np.arange(1, len(nse_sorted_finetuned) + 1) / len(nse_sorted_finetuned)
cum_probs_single_basin = np.arange(1, len(nse_sorted_single_basin) + 1) / len(nse_sorted_single_basin)
cum_probs_multi_basin = np.arange(1, len(nse_sorted_multi_basin) + 1) / len(nse_sorted_multi_basin)

# Plot the ECDFs
plt.figure(figsize=(8, 4))
plt.plot(nse_sorted_multi_basin, cum_probs_multi_basin, linestyle='-', label='Multi Basin (Regional)')
plt.plot(nse_sorted_finetuned, cum_probs_finetuned, linestyle='-', label='Multi Basin (Finetuned)')
plt.plot(nse_sorted_single_basin, cum_probs_single_basin, linestyle='-', label='Single Basin')
plt.xlabel('NSE')
plt.ylabel('Cumulative Density')
# plt.title('ECDF of NSE Values for the Soese Catchment')
plt.ylim(-0.05, 1.05)
plt.grid(True)
plt.legend()
plt.tight_layout()
# save as png in high resolution
# plt.savefig("ecdf_nse_soese.png", dpi=300)
plt.show()
