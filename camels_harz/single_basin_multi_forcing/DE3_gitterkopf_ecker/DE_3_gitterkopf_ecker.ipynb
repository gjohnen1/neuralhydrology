# %%
# import libraries
import yaml
from pathlib import Path
from neuralhydrology.utils.configutils import create_config_files
from neuralhydrology.nh_run_scheduler import schedule_runs
from neuralhydrology.evaluation.tuning import generate_run_dir_patterns
from neuralhydrology.evaluation.tuning import get_best_model_per_seed
from neuralhydrology.nh_run import eval_run
import pickle
import matplotlib.pyplot as plt

# %% [markdown]
# ### Perform two stage hyperparametertuning

# %% [markdown]
# 1. **Stage**:
#    - Use three repetitions of each hyperparameter setting with different random seeds for initializing the weights.
#    - All models are run for 100 epochs using the Adam optimizer with:
#      - Learning rate: 5e−3
#      - Batch size: 256
#    - During training, the model is validated after every 4 epochs on validation period data.

# %%
# Create grid for first stage
grid1 = {
    'hidden_size': [8, 16, 32, 64],  # Hidden size
    'output_dropout': [0.0, 0.2, 0.4, 0.5],  # Dropout rate on the head layer
    'seed': [123, 999, 321]  # Use three repetitions of each hyperparameter setting with different random seeds
}
# Create configs for all possible parameter combinations
# create_config_files(base_config_path=Path('base_stage1.yml'), modify_dict=grid1, output_dir=Path('configs_stage1'))

# %%
# Train models for all configs from one call of the first stage
schedule_runs(mode='train', directory=Path('configs_stage1'), gpu_ids=[0], runs_per_gpu=2)

# %%
# Get run directories for the first stage
run_patterns = generate_run_dir_patterns(grid1, 'single_basin_multi_forcing')

# %%
# Get best model for each seed
best_models_per_seed = get_best_model_per_seed(parent_dir='runs', seeds=grid1['seed'], grid_params=list(grid1.keys())[:-1], run_patterns=run_patterns)
# Out:
# Evaluating repetition for seed 123.
# Evaluating repetition for seed 999.
# Evaluating repetition for seed 321.
# Finished.

# %%
# Print epoch, median NSE, and hyperparameters for each seed
def print_grid_parameters(best_models_per_seed, grid_params):
    for seed, result in best_models_per_seed.items():
        if result['best_model_config'] is not None:
            config = result['best_model_config']
            params = {k: config.get(k) for k in grid_params if k in config}
            print(f"Seed: {seed}")
            print(f"Best epoch: {result['best_epoch']}")
            print(f"Best median NSE score: {result['best_nse']}")
            print(f"Parameters: {params}")
            print()
print_grid_parameters(best_models_per_seed, list(grid1.keys())[:-1])
# Out:
# Seed: 123
# Best epoch: 7
# Best median NSE score: 0.8968254402279854
# Parameters: {'hidden_size': 64, 'output_dropout': 0.2}
#
# Seed: 999
# Best epoch: 10
# Best median NSE score: 0.8739027082920074
# Parameters: {'hidden_size': 32, 'output_dropout': 0.5}
#
# Seed: 321
# Best epoch: 5
# Best median NSE score: 0.8923488631844521
# Parameters: {'hidden_size': 64, 'output_dropout': 0.4}

# %%
# Chose overall best model and hyperparameters based on median NSE for stage 1 and write parameters to a dictionary
best_model = None
best_nse = -float('inf')
best_seed = None
best_params1 = None

for seed, result in best_models_per_seed.items():
    if result['best_nse'] > best_nse:
        best_nse = result['best_nse']
        best_model = result['best_model_dir']
        # best params excluding the seed
        best_params1 = {k: v for k, v in result['best_model_config'].items() if k in grid1}

# %% [markdown]
# 2. **Stage**:
#    - Using the hyperparameters chosen from the first stage, we tune the learning rate and batch size  in a similar way, maximizing over the median NSE over 3 model repetitions.
#    - All models are run again for 100 epochs using the Adam optimizer.
#    - During training, the model is validated after every 4 epochs on validation period data.

# %%
# Create config file for the second stage including hyperparameters of the best model from the first stage
# Read in the base.yml file and replace the hyperparameters with the best hyperparameters from the first stage
with open('base_stage1.yml', 'r') as file:
    base_config = yaml.safe_load(file)

# Update the base config with the best hyperparameters from the first stage
base_config.update(best_params1)

# Save updated config to a new file
with open('base_stage2.yml', 'w') as file:
    yaml.dump(base_config, file)

# Create grid for second stage
grid2 = {
    'learning_rate': [0.01, 0.001, 0.0001],  # Learning rate
    'batch_size': [32, 64, 128],  # Batch size
    'seed': [123, 999, 321]  # Use three repetitions of each hyperparameter setting with different random seeds
}

create_config_files(base_config_path=Path('base_stage2.yml'), modify_dict=grid2, output_dir=Path('configs_stage2'))
# Out:
# Finished. Configs are stored in configs_stage2

# %%
# Train models for all configs from one call of stage 2
schedule_runs(mode='train', directory=Path('configs_stage2'), gpu_ids=[0], runs_per_gpu=2)
# Out:
# Starting run 1/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_4.yml --gpu 0
# Starting run 2/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_1.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_4.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_4.yml into directory of processed configs at configs_stage2/processed/config_4.yml.
# Starting run 3/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_14.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_1.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_1.yml into directory of processed configs at configs_stage2/processed/config_1.yml.
# Starting run 4/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_25.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_14.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_14.yml into directory of processed configs at configs_stage2/processed/config_14.yml.
# Starting run 5/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_8.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_25.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_25.yml into directory of processed configs at configs_stage2/processed/config_25.yml.
# Starting run 6/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_6.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_8.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_8.yml into directory of processed configs at configs_stage2/processed/config_8.yml.
# Starting run 7/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_9.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_9.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_9.yml into directory of processed configs at configs_stage2/processed/config_9.yml.
# Starting run 8/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_20.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_6.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_6.yml into directory of processed configs at configs_stage2/processed/config_6.yml.
# Starting run 9/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_10.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_20.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_20.yml into directory of processed configs at configs_stage2/processed/config_20.yml.
# Starting run 10/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_12.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_10.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_10.yml into directory of processed configs at configs_stage2/processed/config_10.yml.
# Starting run 11/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_7.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_7.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_7.yml into directory of processed configs at configs_stage2/processed/config_7.yml.
# Starting run 12/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_11.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_12.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_12.yml into directory of processed configs at configs_stage2/processed/config_12.yml.
# Starting run 13/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_19.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_11.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_11.yml into directory of processed configs at configs_stage2/processed/config_11.yml.
# Starting run 14/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_23.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_19.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_19.yml into directory of processed configs at configs_stage2/processed/config_19.yml.
# Starting run 15/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_27.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_23.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_23.yml into directory of processed configs at configs_stage2/processed/config_23.yml.
# Starting run 16/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_17.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_27.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_27.yml into directory of processed configs at configs_stage2/processed/config_27.yml.
# Starting run 17/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_26.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_17.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_17.yml into directory of processed configs at configs_stage2/processed/config_17.yml.
# Starting run 18/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_5.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_26.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_26.yml into directory of processed configs at configs_stage2/processed/config_26.yml.
# Starting run 19/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_22.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_5.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_5.yml into directory of processed configs at configs_stage2/processed/config_5.yml.
# Starting run 20/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_18.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_22.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_22.yml into directory of processed configs at configs_stage2/processed/config_22.yml.
# Starting run 21/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_2.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_18.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_18.yml into directory of processed configs at configs_stage2/processed/config_18.yml.
# Starting run 22/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_3.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_2.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_2.yml into directory of processed configs at configs_stage2/processed/config_2.yml.
# Starting run 23/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_21.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_3.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_3.yml into directory of processed configs at configs_stage2/processed/config_3.yml.
# Starting run 24/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_16.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_16.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_16.yml into directory of processed configs at configs_stage2/processed/config_16.yml.
# Starting run 25/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_13.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_13.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_13.yml into directory of processed configs at configs_stage2/processed/config_13.yml.
# Starting run 26/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_24.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_21.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_21.yml into directory of processed configs at configs_stage2/processed/config_21.yml.
# Starting run 27/27: python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_15.yml --gpu 0
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_24.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_24.yml into directory of processed configs at configs_stage2/processed/config_24.yml.
# Finished run python /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/nh_run.py train --config-file /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_15.yml --gpu 0
# Cleaning up...
#
#
# Moved /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/single_basin_multi_forcing/DE4_riefensbeek_soese/configs_stage2/config_15.yml into directory of processed configs at configs_stage2/processed/config_15.yml.
# Done

# %%
# Get run directories for the second stage
run_patterns = generate_run_dir_patterns(grid2, 'single_basin_multi_forcing')

# %%
# Get best model for each seed
best_models_per_seed = get_best_model_per_seed(parent_dir='runs', seeds=grid2['seed'], grid_params=list(grid2.keys())[:-1], run_patterns=run_patterns)
# Out:
# Evaluating repetition for seed 123.
# Evaluating repetition for seed 999.
# Evaluating repetition for seed 321.
# Finished.

# %%
# Print epoch, median NSE, and hyperparameters for each seed
print_grid_parameters(best_models_per_seed, list(grid2.keys())[:-1])
# Out:
# Seed: 123
# Best epoch: 22
# Best median NSE score: 0.8738305121660233
# Parameters: {'learning_rate': 0.001, 'batch_size': 32}
#
# Seed: 999
# Best epoch: 22
# Best median NSE score: 0.8846791312098503
# Parameters: {'learning_rate': 0.001, 'batch_size': 32}
#
# Seed: 321
# Best epoch: 18
# Best median NSE score: 0.8760613650083542
# Parameters: {'learning_rate': 0.001, 'batch_size': 64}

# %%
# Chose overall best model and hyperparameters based on median NSE for stage 2 and write parameters to a dictionary
best_model = None
best_nse = -float('inf')
best_seed = None
best_params2 = None

for seed, result in best_models_per_seed.items():
    if result['best_nse'] > best_nse:
        best_nse = result['best_nse']
        best_model = result['best_model_dir']
        best_epoch = f"{result['best_epoch']}"
        # best params excluding the seed
        best_params2 = {k: v for k, v in result['best_model_config'].items() if k in grid2}

# %%
# Create config file for the second stage including hyperparameters of the best model from the first stage
# Read in the base.yml file and replace the hyperparameters with the best hyperparameters from the first stage
with open('base_stage2.yml', 'r') as file:
    base_config = yaml.safe_load(file)

# Update the base config with the best hyperparameters from the first stage
base_config.update(best_params2)

# Save the updated config to a new file
with open('base_final.yml', 'w') as file:
    yaml.dump(base_config, file)

# %% [markdown]
# ### Evaluate run on test set
# The path to the best model is automatically saved in the variable best_model, and the corresponding best epoch is stored as a string in best_epoch.

# %%
eval_run(run_dir=best_model, period="test", epoch=best_epoch)
# Out:
# # Evaluation: 100%|██████████| 1/1 [00:00<00:00,  2.60it/s]

# %% [markdown]
# ### Load and inspect model predictions
# Load the results file and compare the model predictions with observations. The results file is always a pickled dictionary with one key per basin (even for a single basin). The next-lower dictionary level is the temporal resolution of the predictions. In this case, we trained a model only on daily data ('1D'). Within the temporal resolution, the next-lower dictionary level are `xr`(an xarray Dataset that contains observations and predictions), as well as one key for each metric that was specified in the config file.

# %%
with open(best_model / "test" / f"model_epoch0{best_epoch}" / "test_results.p", "rb") as fp:
    results = pickle.load(fp)
    
results.keys()
# Out:
# dict_keys(['DE4'])

# %%
results['DE4']['1D']['xr']
# Out:
# <xarray.Dataset>
# Dimensions:            (date: 823, time_step: 1)
# Coordinates:
#   * date               (date) datetime64[ns] 2018-10-01 ... 2020-12-31
#   * time_step          (time_step) int64 0
# Data variables:
#     discharge_vol_obs  (date, time_step) float32 0.06 0.17 0.23 ... 0.52 0.47
#     discharge_vol_sim  (date, time_step) float32 0.05546 0.147 ... 0.5148 0.4718

# %%
# Extract observations and simulations
qobs = results['DE4']['1D']['xr']['discharge_vol_obs']
qsim = results['DE4']['1D']['xr']['discharge_vol_sim']

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("Discharge (mm/d)")
ax.set_title(f"Test period - NSE {results['DE4']['1D']['NSE']:.3f}")
# Out:
# Text(0.5, 1.0, 'Test period - NSE 0.898')
