# %%
import pickle
from pathlib import Path

import matplotlib.pyplot as plt
import torch
from neuralhydrology.evaluation import metrics
from neuralhydrology.nh_run import start_run, eval_run

# %%
# by default it is assumed that at least one CUDA-capable NVIDIA GPU is available
if torch.cuda.is_available():
    start_run(config_file=Path("1_basin.yml"))

# fall back to CPU-only mode
else:
    start_run(config_file=Path("1_basin.yml"), gpu=-1)
# Out:
# 2024-08-02 09:56:17,353: Logging to /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/runs/test_run_0208_095617/output.log initialized.
# 2024-08-02 09:56:17,354: ### Folder structure created at /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/runs/test_run_0208_095617
# 2024-08-02 09:56:17,354: ### Run configurations for test_run
# 2024-08-02 09:56:17,354: experiment_name: test_run
# 2024-08-02 09:56:17,355: train_basin_file: 1_basin.txt
# 2024-08-02 09:56:17,355: validation_basin_file: 1_basin.txt
# 2024-08-02 09:56:17,355: test_basin_file: 1_basin.txt
# 2024-08-02 09:56:17,355: train_start_date: 1970-10-01 00:00:00
# 2024-08-02 09:56:17,355: train_end_date: 2018-09-30 00:00:00
# 2024-08-02 09:56:17,355: validation_start_date: 1955-10-01 00:00:00
# 2024-08-02 09:56:17,356: validation_end_date: 1965-09-30 00:00:00
# 2024-08-02 09:56:17,356: test_start_date: 1965-10-01 00:00:00
# 2024-08-02 09:56:17,356: test_end_date: 1970-09-30 00:00:00
# 2024-08-02 09:56:17,356: device: cuda:0
# 2024-08-02 09:56:17,356: validate_every: 3
# 2024-08-02 09:56:17,357: validate_n_random_basins: 1
# 2024-08-02 09:56:17,358: metrics: ['NSE']
# 2024-08-02 09:56:17,358: model: cudalstm
# 2024-08-02 09:56:17,358: head: regression
# 2024-08-02 09:56:17,358: output_activation: linear
# 2024-08-02 09:56:17,358: hidden_size: 20
# 2024-08-02 09:56:17,359: initial_forget_bias: 3
# 2024-08-02 09:56:17,359: output_dropout: 0.4
# 2024-08-02 09:56:17,359: optimizer: Adam
# 2024-08-02 09:56:17,359: loss: MSE
# 2024-08-02 09:56:17,359: learning_rate: {0: 0.01, 30: 0.005, 40: 0.001}
# 2024-08-02 09:56:17,360: batch_size: 256
# 2024-08-02 09:56:17,360: epochs: 50
# 2024-08-02 09:56:17,360: clip_gradient_norm: 1
# 2024-08-02 09:56:17,360: predict_last_n: 1
# 2024-08-02 09:56:17,361: seq_length: 365
# 2024-08-02 09:56:17,361: num_workers: 8
# 2024-08-02 09:56:17,361: log_interval: 5
# 2024-08-02 09:56:17,362: log_tensorboard: True
# 2024-08-02 09:56:17,362: log_n_figures: 1
# 2024-08-02 09:56:17,362: save_weights_every: 1
# 2024-08-02 09:56:17,362: dataset: camels_de
# 2024-08-02 09:56:17,362: data_dir: ../data/camels_de
# 2024-08-02 09:56:17,363: dynamic_inputs: ['precipitation_mean', 'precipitation_min', 'precipitation_max', 'humidity_mean', 'humidity_min', 'humidity_max', 'radiation_global_mean', 'radiation_global_min', 'radiation_global_max', 'temperature_mean', 'temperature_min', 'temperature_max']
# 2024-08-02 09:56:17,363: target_variables: ['discharge_vol']
# 2024-08-02 09:56:17,363: static_attributes: ['p_mean', 'p_seasonality', 'aquitard_perc', 'aquifer_perc', 'artificial_surfaces_perc', 'agricultural_areas_perc', 'forests_and_seminatural_areas_perc', 'wetlands_perc', 'q_mean', 'runoff_ratio', 'slope_fdc']
# 2024-08-02 09:56:17,363: number_of_basins: 5
# 2024-08-02 09:56:17,363: run_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/runs/test_run_0208_095617
# 2024-08-02 09:56:17,363: train_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/runs/test_run_0208_095617/train_data
# 2024-08-02 09:56:17,364: img_log_dir: /home/sngrj0hn/GitHub/neuralhydrology/camels_harz/runs/test_run_0208_095617/img_log
# 2024-08-02 09:56:17,365: ### Device cuda:0 will be used for training
# 2024-08-02 09:56:17,386: Loading basin data into xarray data set.
# 100%|██████████| 5/5 [00:00<00:00, 38.14it/s]
# 2024-08-02 09:56:17,526: Create lookup table and convert to pytorch tensor
# 100%|██████████| 5/5 [00:00<00:00,  9.44it/s]
# # Epoch 1: 100%|██████████| 316/316 [00:01<00:00, 198.25it/s, Loss: 0.0240]
# 2024-08-02 09:56:19,690: Epoch 1 average loss: avg_loss: 0.20511, avg_total_loss: 0.20511
# # Epoch 2: 100%|██████████| 316/316 [00:01<00:00, 199.53it/s, Loss: 0.0369]
# 2024-08-02 09:56:21,277: Epoch 2 average loss: avg_loss: 0.13227, avg_total_loss: 0.13227
# # Epoch 3: 100%|██████████| 316/316 [00:01<00:00, 203.10it/s, Loss: 0.0164]
# 2024-08-02 09:56:22,835: Epoch 3 average loss: avg_loss: 0.11374, avg_total_loss: 0.11374
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 10.08it/s]
# 2024-08-02 09:56:23,091: Epoch 3 average validation loss: 0.06629 -- Median validation metrics: avg_loss: 0.06629, NSE: 0.76385
# # Epoch 4: 100%|██████████| 316/316 [00:01<00:00, 203.30it/s, Loss: 0.0353]
# 2024-08-02 09:56:24,647: Epoch 4 average loss: avg_loss: 0.10990, avg_total_loss: 0.10990
# # Epoch 5: 100%|██████████| 316/316 [00:01<00:00, 206.94it/s, Loss: 0.1087]
# 2024-08-02 09:56:26,177: Epoch 5 average loss: avg_loss: 0.10886, avg_total_loss: 0.10886
# # Epoch 6: 100%|██████████| 316/316 [00:01<00:00, 200.17it/s, Loss: 0.0476]
# 2024-08-02 09:56:27,758: Epoch 6 average loss: avg_loss: 0.10323, avg_total_loss: 0.10323
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.54it/s]
# 2024-08-02 09:56:27,947: Epoch 6 average validation loss: 0.04665 -- Median validation metrics: avg_loss: 0.04665, NSE: 0.83479
# # Epoch 7: 100%|██████████| 316/316 [00:01<00:00, 200.02it/s, Loss: 0.0383]
# 2024-08-02 09:56:29,529: Epoch 7 average loss: avg_loss: 0.10826, avg_total_loss: 0.10826
# # Epoch 8: 100%|██████████| 316/316 [00:01<00:00, 197.42it/s, Loss: 0.0483]
# 2024-08-02 09:56:31,133: Epoch 8 average loss: avg_loss: 0.09788, avg_total_loss: 0.09788
# # Epoch 9: 100%|██████████| 316/316 [00:01<00:00, 199.12it/s, Loss: 0.0163]
# 2024-08-02 09:56:32,722: Epoch 9 average loss: avg_loss: 0.10381, avg_total_loss: 0.10381
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 10.61it/s]
# 2024-08-02 09:56:32,955: Epoch 9 average validation loss: 0.02310 -- Median validation metrics: avg_loss: 0.02310, NSE: 0.64211
# # Epoch 10: 100%|██████████| 316/316 [00:01<00:00, 194.56it/s, Loss: 0.0371]
# 2024-08-02 09:56:34,581: Epoch 10 average loss: avg_loss: 0.09925, avg_total_loss: 0.09925
# # Epoch 11: 100%|██████████| 316/316 [00:01<00:00, 201.80it/s, Loss: 0.0135]
# 2024-08-02 09:56:36,150: Epoch 11 average loss: avg_loss: 0.09388, avg_total_loss: 0.09388
# # Epoch 12: 100%|██████████| 316/316 [00:01<00:00, 196.84it/s, Loss: 0.2051]
# 2024-08-02 09:56:37,758: Epoch 12 average loss: avg_loss: 0.09998, avg_total_loss: 0.09998
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.01it/s]
# 2024-08-02 09:56:38,236: Epoch 12 average validation loss: nan -- Median validation metrics: avg_loss: nan
# # Epoch 13: 100%|██████████| 316/316 [00:01<00:00, 202.81it/s, Loss: 0.2025]
# 2024-08-02 09:56:39,796: Epoch 13 average loss: avg_loss: 0.09575, avg_total_loss: 0.09575
# # Epoch 14: 100%|██████████| 316/316 [00:01<00:00, 195.28it/s, Loss: 0.0747]
# 2024-08-02 09:56:41,416: Epoch 14 average loss: avg_loss: 0.10600, avg_total_loss: 0.10600
# # Epoch 15: 100%|██████████| 316/316 [00:01<00:00, 194.62it/s, Loss: 0.0891]
# 2024-08-02 09:56:43,043: Epoch 15 average loss: avg_loss: 0.09904, avg_total_loss: 0.09904
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.81it/s]
# 2024-08-02 09:56:43,227: Epoch 15 average validation loss: 0.01784 -- Median validation metrics: avg_loss: 0.01784, NSE: 0.72394
# # Epoch 16: 100%|██████████| 316/316 [00:01<00:00, 202.93it/s, Loss: 0.0284]
# 2024-08-02 09:56:44,786: Epoch 16 average loss: avg_loss: 0.10145, avg_total_loss: 0.10145
# # Epoch 17: 100%|██████████| 316/316 [00:01<00:00, 192.31it/s, Loss: 0.1692]
# 2024-08-02 09:56:46,431: Epoch 17 average loss: avg_loss: 0.09819, avg_total_loss: 0.09819
# # Epoch 18: 100%|██████████| 316/316 [00:01<00:00, 207.34it/s, Loss: 0.0675]
# 2024-08-02 09:56:47,958: Epoch 18 average loss: avg_loss: 0.09196, avg_total_loss: 0.09196
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 24.74it/s]
# 2024-08-02 09:56:48,150: Epoch 18 average validation loss: 0.06209 -- Median validation metrics: avg_loss: 0.06209, NSE: 0.77951
# # Epoch 19: 100%|██████████| 316/316 [00:01<00:00, 205.65it/s, Loss: 0.0424]
# 2024-08-02 09:56:49,688: Epoch 19 average loss: avg_loss: 0.08935, avg_total_loss: 0.08935
# # Epoch 20: 100%|██████████| 316/316 [00:01<00:00, 198.80it/s, Loss: 0.0257]
# 2024-08-02 09:56:51,281: Epoch 20 average loss: avg_loss: 0.09036, avg_total_loss: 0.09036
# # Epoch 21: 100%|██████████| 316/316 [00:01<00:00, 200.46it/s, Loss: 0.0144]
# 2024-08-02 09:56:52,860: Epoch 21 average loss: avg_loss: 0.09405, avg_total_loss: 0.09405
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 24.72it/s]
# 2024-08-02 09:56:53,050: Epoch 21 average validation loss: 0.02113 -- Median validation metrics: avg_loss: 0.02113, NSE: 0.67402
# # Epoch 22: 100%|██████████| 316/316 [00:01<00:00, 167.72it/s, Loss: 0.1559]
# 2024-08-02 09:56:54,936: Epoch 22 average loss: avg_loss: 0.09970, avg_total_loss: 0.09970
# # Epoch 23: 100%|██████████| 316/316 [00:01<00:00, 170.97it/s, Loss: 0.0426]
# 2024-08-02 09:56:56,787: Epoch 23 average loss: avg_loss: 0.09524, avg_total_loss: 0.09524
# # Epoch 24: 100%|██████████| 316/316 [00:01<00:00, 177.36it/s, Loss: 0.0796]
# 2024-08-02 09:56:58,572: Epoch 24 average loss: avg_loss: 0.10027, avg_total_loss: 0.10027
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  4.80it/s]
# 2024-08-02 09:56:58,933: Epoch 24 average validation loss: 0.02669 -- Median validation metrics: avg_loss: 0.02669, NSE: 0.84145
# # Epoch 25: 100%|██████████| 316/316 [00:01<00:00, 203.11it/s, Loss: 0.0595]
# 2024-08-02 09:57:00,491: Epoch 25 average loss: avg_loss: 0.09646, avg_total_loss: 0.09646
# # Epoch 26: 100%|██████████| 316/316 [00:01<00:00, 203.41it/s, Loss: 0.1659]
# 2024-08-02 09:57:02,048: Epoch 26 average loss: avg_loss: 0.09587, avg_total_loss: 0.09587
# # Epoch 27: 100%|██████████| 316/316 [00:01<00:00, 194.16it/s, Loss: 0.1050]
# 2024-08-02 09:57:03,678: Epoch 27 average loss: avg_loss: 0.08980, avg_total_loss: 0.08980
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  2.05it/s]
# 2024-08-02 09:57:04,296: Epoch 27 average validation loss: 0.05249 -- Median validation metrics: avg_loss: 0.05249, NSE: 0.83032
# # Epoch 28: 100%|██████████| 316/316 [00:01<00:00, 199.59it/s, Loss: 0.0545]
# 2024-08-02 09:57:05,881: Epoch 28 average loss: avg_loss: 0.09435, avg_total_loss: 0.09435
# # Epoch 29: 100%|██████████| 316/316 [00:01<00:00, 204.78it/s, Loss: 0.0989]
# 2024-08-02 09:57:07,428: Epoch 29 average loss: avg_loss: 0.10002, avg_total_loss: 0.10002
# 2024-08-02 09:57:07,430: Setting learning rate to 0.005
# # Epoch 30: 100%|██████████| 316/316 [00:01<00:00, 195.45it/s, Loss: 0.0201]
# 2024-08-02 09:57:09,048: Epoch 30 average loss: avg_loss: 0.08675, avg_total_loss: 0.08675
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
# 2024-08-02 09:57:09,475: Epoch 30 average validation loss: nan -- Median validation metrics: avg_loss: nan
# # Epoch 31: 100%|██████████| 316/316 [00:01<00:00, 200.51it/s, Loss: 0.0082]
# 2024-08-02 09:57:11,053: Epoch 31 average loss: avg_loss: 0.07803, avg_total_loss: 0.07803
# # Epoch 32: 100%|██████████| 316/316 [00:01<00:00, 198.42it/s, Loss: 0.1954]
# 2024-08-02 09:57:12,650: Epoch 32 average loss: avg_loss: 0.07830, avg_total_loss: 0.07830
# # Epoch 33: 100%|██████████| 316/316 [00:01<00:00, 197.49it/s, Loss: 0.0287]
# 2024-08-02 09:57:14,254: Epoch 33 average loss: avg_loss: 0.07593, avg_total_loss: 0.07593
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.41it/s]
# 2024-08-02 09:57:14,439: Epoch 33 average validation loss: 0.02669 -- Median validation metrics: avg_loss: 0.02669, NSE: 0.84351
# # Epoch 34: 100%|██████████| 316/316 [00:01<00:00, 204.22it/s, Loss: 0.0886]
# 2024-08-02 09:57:15,989: Epoch 34 average loss: avg_loss: 0.07798, avg_total_loss: 0.07798
# # Epoch 35: 100%|██████████| 316/316 [00:01<00:00, 198.38it/s, Loss: 0.1147]
# 2024-08-02 09:57:17,585: Epoch 35 average loss: avg_loss: 0.07668, avg_total_loss: 0.07668
# # Epoch 36: 100%|██████████| 316/316 [00:01<00:00, 203.54it/s, Loss: 0.0433]
# 2024-08-02 09:57:19,141: Epoch 36 average loss: avg_loss: 0.07699, avg_total_loss: 0.07699
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 24.51it/s]
# 2024-08-02 09:57:19,331: Epoch 36 average validation loss: 0.05656 -- Median validation metrics: avg_loss: 0.05656, NSE: 0.79917
# # Epoch 37: 100%|██████████| 316/316 [00:01<00:00, 197.56it/s, Loss: 0.0384]
# 2024-08-02 09:57:20,932: Epoch 37 average loss: avg_loss: 0.07597, avg_total_loss: 0.07597
# # Epoch 38: 100%|██████████| 316/316 [00:01<00:00, 192.80it/s, Loss: 0.0089]
# 2024-08-02 09:57:22,575: Epoch 38 average loss: avg_loss: 0.07579, avg_total_loss: 0.07579
# # Epoch 39: 100%|██████████| 316/316 [00:01<00:00, 201.48it/s, Loss: 0.0306]
# 2024-08-02 09:57:24,146: Epoch 39 average loss: avg_loss: 0.07128, avg_total_loss: 0.07128
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 23.14it/s]
# 2024-08-02 09:57:24,327: Epoch 39 average validation loss: 0.01589 -- Median validation metrics: avg_loss: 0.01589, NSE: 0.75258
# 2024-08-02 09:57:24,328: Setting learning rate to 0.001
# # Epoch 40: 100%|██████████| 316/316 [00:01<00:00, 193.55it/s, Loss: 0.0322]
# 2024-08-02 09:57:25,962: Epoch 40 average loss: avg_loss: 0.06660, avg_total_loss: 0.06660
# # Epoch 41: 100%|██████████| 316/316 [00:01<00:00, 194.64it/s, Loss: 0.1067]
# 2024-08-02 09:57:27,588: Epoch 41 average loss: avg_loss: 0.06827, avg_total_loss: 0.06827
# # Epoch 42: 100%|██████████| 316/316 [00:01<00:00, 200.40it/s, Loss: 0.0116]
# 2024-08-02 09:57:29,168: Epoch 42 average loss: avg_loss: 0.06995, avg_total_loss: 0.06995
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# 2024-08-02 09:57:29,586: Epoch 42 average validation loss: nan -- Median validation metrics: avg_loss: nan
# # Epoch 43: 100%|██████████| 316/316 [00:01<00:00, 207.21it/s, Loss: 0.0576]
# 2024-08-02 09:57:31,113: Epoch 43 average loss: avg_loss: 0.06418, avg_total_loss: 0.06418
# # Epoch 44: 100%|██████████| 316/316 [00:01<00:00, 202.25it/s, Loss: 0.0191]
# 2024-08-02 09:57:32,679: Epoch 44 average loss: avg_loss: 0.06568, avg_total_loss: 0.06568
# # Epoch 45: 100%|██████████| 316/316 [00:01<00:00, 205.53it/s, Loss: 0.0053]
# 2024-08-02 09:57:34,219: Epoch 45 average loss: avg_loss: 0.06427, avg_total_loss: 0.06427
# # Validation: 100%|██████████| 1/1 [00:00<00:00, 19.71it/s]
# 2024-08-02 09:57:34,414: Epoch 45 average validation loss: 0.04867 -- Median validation metrics: avg_loss: 0.04867, NSE: 0.82711
# # Epoch 46: 100%|██████████| 316/316 [00:01<00:00, 201.64it/s, Loss: 0.0185]
# 2024-08-02 09:57:35,983: Epoch 46 average loss: avg_loss: 0.06565, avg_total_loss: 0.06565
# # Epoch 47: 100%|██████████| 316/316 [00:01<00:00, 198.72it/s, Loss: 0.0286]
# 2024-08-02 09:57:37,575: Epoch 47 average loss: avg_loss: 0.06668, avg_total_loss: 0.06668
# # Epoch 48: 100%|██████████| 316/316 [00:01<00:00, 195.95it/s, Loss: 0.0325]
# 2024-08-02 09:57:39,191: Epoch 48 average loss: avg_loss: 0.06210, avg_total_loss: 0.06210
# # Validation: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# 2024-08-02 09:57:39,606: Epoch 48 average validation loss: nan -- Median validation metrics: avg_loss: nan
# # Epoch 49: 100%|██████████| 316/316 [00:01<00:00, 191.52it/s, Loss: 0.0929]
# 2024-08-02 09:57:41,258: Epoch 49 average loss: avg_loss: 0.06529, avg_total_loss: 0.06529
# # Epoch 50: 100%|██████████| 316/316 [00:01<00:00, 201.03it/s, Loss: 0.0310]
# 2024-08-02 09:57:42,832: Epoch 50 average loss: avg_loss: 0.06417, avg_total_loss: 0.06417

# %% [markdown]
# ### Evaluate run on test set

# %%
# Set the directory for model evaluation. This directory is dynamically generated and includes the date
# and time at the start of the model run. Users must specify `run_dir` based on the actual directory
# name created during the run. The directory naming convention typically reflects the date and time of
# the model execution, as shown below. By default, the evaluation will occur on the same device used
# during training.

run_dir = Path("runs/test_run_0208_095617")  # Example path to the dynamically created run directory.
eval_run(run_dir=run_dir, period="test")  # Initiate model evaluation for the 'test' period.
# Out:
# 2024-08-02 09:58:10,808: Using the model weights from runs/test_run_0208_095617/model_epoch050.pt
# # Evaluation: 100%|██████████| 5/5 [00:00<00:00, 10.24it/s]
# 2024-08-02 09:58:11,300: Stored metrics at runs/test_run_0208_095617/test/model_epoch050/test_metrics.csv
# 2024-08-02 09:58:11,301: Stored results at runs/test_run_0208_095617/test/model_epoch050/test_results.p

# %% [markdown]
# ### Load and inspect model predictions

# %%
# Load the model's test results from a pickle file located in a specified directory. The structure
# of the results file is a nested dictionary, organized as follows:
# - The top-level dictionary has one key for each basin, even if only a single basin was analyzed.
# - Each basin key leads to a sub-dictionary where keys represent the temporal resolution of the data.
#   In this case, '1D' indicates daily data.
# - At this level, the dictionary includes:
#   - An 'xr' key, containing an xarray Dataset with both observations and model predictions.
#   - Additional keys corresponding to each metric specified in the configuration file, holding
#     their respective results.

# Example path to the results file:
results_path = run_dir / "test" / "model_epoch050" / "test_results.p"
with open(results_path, "rb") as fp:
    results = pickle.load(fp)  # Load the results from the pickle file
    
# Print the keys from the loaded results, typically basin identifiers
results.keys()
# Out:
# dict_keys(['DE1', 'DE2', 'DE3', 'DE4', 'DE5'])

# %% [markdown]
# The data variables in the xarray Dataset are named according to the name of the target variables, with suffix `_obs` for the observations and suffix `_sim` for the simulations.

# %%
results['DE1']['1D']['xr']
# Out:
# <xarray.Dataset>
# Dimensions:            (date: 1826, time_step: 1)
# Coordinates:
#   * date               (date) datetime64[ns] 1965-10-01 ... 1970-09-30
#   * time_step          (time_step) int64 0
# Data variables:
#     discharge_vol_obs  (date, time_step) float32 0.4 0.4 0.32 ... 0.47 0.39 0.85
#     discharge_vol_sim  (date, time_step) float32 0.3647 0.3738 ... 0.5686 0.758

# %% [markdown]
# Let's plot the model predictions vs. the observations

# %%
# extract observations and simulations
qobs = results['DE3']['1D']['xr']['discharge_vol_obs']
qsim = results['DE3']['1D']['xr']['discharge_vol_sim']

fig, ax = plt.subplots(figsize=(16,10))
ax.plot(qobs['date'], qobs)
ax.plot(qsim['date'], qsim)
ax.set_ylabel("Discharge (mm/d)")
ax.set_title(f"Test period - NSE {results['DE3']['1D']['NSE']:.3f}")
# Out:
# Text(0.5, 1.0, 'Test period - NSE 0.764')

# %% [markdown]
# Compute all metrics that implemented in the NeuralHydrology package. Additional hydrological signatures implemented in `neuralhydrology.evaluation.signatures`.

# %%
values = metrics.calculate_all_metrics(qobs.isel(time_step=-1), qsim.isel(time_step=-1))
for key, val in values.items():
    print(f"{key}: {val:.3f}")
# Out:
# NSE: 0.741
# MSE: 0.580
# RMSE: 0.761
# KGE: 0.819
# Alpha-NSE: 0.892
# Beta-KGE: 1.046
# Beta-NSE: 0.029
# Pearson-r: 0.862
# FHV: -14.047
# FMS: 2.932
# FLV: -20.736
# Peak-Timing: 0.091
# Peak-MAPE: 34.654
# /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/datautils/utils.py:327: FutureWarning: 'H' is deprecated and will be removed in a future version, please use 'h' instead.
#   offset_one = to_offset(freq_one)
# /home/sngrj0hn/GitHub/neuralhydrology/neuralhydrology/datautils/utils.py:368: FutureWarning: 'H' is deprecated and will be removed in a future version. Please use 'h' instead of 'H'.
#   factor = pd.to_timedelta(freq_one) / pd.to_timedelta(freq_two)
